# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("wine_data.csv")

# %%
df
# Out:
#      class_label  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0              1    14.23        1.71  2.43               15.6        127
# 1              1    13.20        1.78  2.14               11.2        100
# 2              1    13.16        2.36  2.67               18.6        101
# 3              1    14.37        1.95  2.50               16.8        113
# 4              1    13.24        2.59  2.87               21.0        118
# ..           ...      ...         ...   ...                ...        ...
# 173            3    13.71        5.65  2.45               20.5         95
# 174            3    13.40        3.91  2.48               23.0        102
# 175            3    13.27        4.28  2.26               20.0        120
# 176            3    13.17        2.59  2.37               20.0        120
# 177            3    14.13        4.10  2.74               24.5         96
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# ...

# %%
X = df.drop("class_label",axis=1)
Y = df[["class_label"]]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# # Min Max Scaler

# %%
#preprocessing using 0-1 scaling
scaler=MinMaxScaler()
scaler.fit(X_train)

X_train_scaled_MMS = scaler.transform(X_train)
X_test_scaled_MMS = scaler.transform(X_test)

# %%
print(X_train_scaled_MMS)
# Out:
# [[0.71505376 0.51323829 0.6344086  ... 0.35897436 0.2014652  0.31026253]
#  [0.44623656 0.16089613 0.48387097 ... 0.35897436 0.28937729 0.16308671]
#  [0.15860215 0.25458248 0.49462366 ... 0.52991453 0.61904762 0.04375497]
#  ...
#  [0.37365591 0.17718941 0.44623656 ... 0.44444444 0.61904762 0.04375497]
#  [0.77150538 0.19144603 0.40860215 ... 0.31623932 0.75457875 0.55290374]
#  [0.84139785 0.3604888  0.60215054 ... 0.06837607 0.16117216 0.29435163]]

# %%
print(X_test_scaled_MMS)
# Out:
# [[ 0.72849462  0.18940937  0.47849462  0.29896907  0.52173913  0.53956835
#    0.74311927  0.1509434   0.37974684  0.38993174  0.32478632  0.70695971
#    0.61256961]
#  [ 0.47311828  0.39307536  0.60215054  0.58762887  0.45652174  0.13669065
#    0.27217125  0.20754717  0.26582278  0.81228669 -0.05128205  0.07326007
#    0.15115354]
#  [ 0.36021505  0.07942974  0.43010753  0.43298969  0.18478261  0.86330935
#    0.80428135  0.11320755  0.45886076  0.27047782  0.58119658  0.58608059
#    0.10342084]
#  [ 0.68010753  0.20162933  0.59139785  0.51030928  0.5         0.66906475
#    0.70642202  0.13207547  0.64240506  0.42406143  0.37606838  0.64468864
#    0.66030231]
#  [ 0.54301075  1.0305499   0.41397849  0.56185567  0.17391304  0.54676259
#    0.66666667  0.32075472  0.50316456  0.11262799  0.16239316  0.67032967
#    0.07159905]
#  [ 0.14247312  0.26680244  1.00537634  0.92268041  0.5326087   0.74820144
#    1.40978593  0.64150943  0.45886076  0.40273038  0.33333333  0.88644689
# ...

# %%
#change scale to -3,3
scaler=MinMaxScaler(feature_range=(-3,3))
scaler.fit(X_train)

X_train_scaled_changed = scaler.transform(X_train)
X_test_scaled_changed = scaler.transform(X_test)

# %%
print(X_train_scaled_changed)
# Out:
# [[ 1.29032258  0.07942974  0.80645161 ... -0.84615385 -1.79120879
#   -1.13842482]
#  [-0.32258065 -2.03462322 -0.09677419 ... -0.84615385 -1.26373626
#   -2.02147971]
#  [-2.0483871  -1.47250509 -0.03225806 ...  0.17948718  0.71428571
#   -2.73747017]
#  ...
#  [-0.75806452 -1.93686354 -0.32258065 ... -0.33333333  0.71428571
#   -2.73747017]
#  [ 1.62903226 -1.85132383 -0.5483871  ... -1.1025641   1.52747253
#    0.31742243]
#  [ 2.0483871  -0.83706721  0.61290323 ... -2.58974359 -2.03296703
#   -1.23389021]]

# %%
print(X_test_scaled_changed)
# Out:
